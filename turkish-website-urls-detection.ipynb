# %% [markdown]
# # Collecting Turkish website URLs
# We have WARC files and news websites list from Basin Ilan Kurumu.\
# First we will try to find websites that have Turkish Content from WARC files. \
# Then we will merge this data with BIK's list.

# %% [markdown]
# ### Install required packages

# %%
pip install warcio tqdm
# Out:
# Requirement already satisfied: warcio in /opt/anaconda3/lib/python3.12/site-packages (1.7.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (4.66.5)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from warcio) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Constants

# %%
import os

data_folder = './data'
warc_files = [os.path.join(data_folder, f) for f in os.listdir(data_folder) if f.endswith('.warc')]
print("WARC dosyaları:", warc_files)
# Out:
# WARC dosyaları: ['./data/CC-NEWS-20250103095544-00180.warc', './data/CC-NEWS-20250102092617-00168.warc', './data/CC-NEWS-20250101055537-00157.warc', './data/CC-NEWS-20250101233509-00164.warc', './data/CC-NEWS-20250102214004-00175.warc', './data/CC-NEWS-20250103181014-00185.warc', './data/CC-NEWS-20250103145501-00183.warc', './data/CC-NEWS-20250101110352-00159.warc', './data/CC-NEWS-20250102074538-00167.warc', './data/CC-NEWS-20250102110149-00169.warc', './data/CC-NEWS-20200110212037-00310.warc', './data/CC-NEWS-20250102140759-00171.warc', './data/CC-NEWS-20250102053830-00166.warc', './data/CC-NEWS-20250103060152-00178.warc', './data/CC-NEWS-20250101182853-00162.warc', './data/CC-NEWS-20250102155145-00172.warc', './data/CC-NEWS-20250101204758-00163.warc', './data/CC-NEWS-20250103080404-00179.warc', './data/CC-NEWS-20250102192440-00174.warc', './data/CC-NEWS-20250102122438-00170.warc', './data/CC-NEWS-20250102173620-00173.warc', './data/CC-NEWS-20250103114344-00181.warc', './data/CC-NEWS-20250101083312-00158.warc', './data/CC-NEWS-20250101160900-00161.warc', './data/CC-NEWS-20250103031223-00177.warc', './data/CC-NEWS-20250103000559-00176.warc', './data/CC-NEWS-20250101133323-00160.warc', './data/CC-NEWS-20250103131849-00182.warc', './data/CC-NEWS-20250103163233-00184.warc', './data/CC-NEWS-20250101020153-00156.warc', './data/CC-NEWS-20250102025043-00165.warc']

# %% [markdown]
# ### Collect URLs that have Turkish content

# %%
import re
from tqdm import tqdm
from warcio.archiveiterator import ArchiveIterator
from urllib.parse import urlparse

def is_turkish_text(content, min_unique=3, debug=False):
    """
    İçerikteki Türkçe karakterler arasında, farklı (unique) karakter sayısı min_unique'ten fazla ise
    içerik Türkçe kabul edilir.
    """
    # Türkçe karakterler: ç, ğ, ı, ö, ş, ü (büyük ve küçük)
    turkish_chars = "çğıöşüÇĞİÖŞÜ"
    matches = re.findall(f"[{turkish_chars}]", content)
    unique_chars = set(matches)
    if debug:
        print(f"Bulunan karakterler: {matches}")
        print(f"Unique karakterler: {unique_chars}")
    return len(unique_chars) > min_unique

def list_turkish_urls_by_chars(warc_file, read_bytes=20000, debug=False):
    """Bir WARC dosyasındaki, içerikte Türkçe karakterlerin varlığına bakarak Türkçe URL'leri döndürür."""
    turkish_urls = []
    try:
        with open(warc_file, 'rb') as f:
            for record in ArchiveIterator(f):
                if record.rec_type == 'response':
                    try:
                        content = record.content_stream().read(read_bytes).decode('utf-8', errors='ignore')
                        if content.strip() and is_turkish_text(content, debug=debug):
                            url = record.rec_headers.get_header('WARC-Target-URI')
                            if url:
                                turkish_urls.append(url)
                    except Exception as error:
                        if debug:
                            print("Record işlenirken hata:", error)
                        continue
    except Exception as e:
        print(f"Error processing {warc_file}: {e}")
    return turkish_urls

# WARC dosyalarını işleyip Türkçe URL'leri toplayalım
all_turkish_urls = []
all_turkish_urls_counts = {}

for warc_file in tqdm(warc_files, desc="Processing WARC files"):
    urls = list_turkish_urls_by_chars(warc_file, debug=False)
    all_turkish_urls_counts[warc_file] = len(urls)
    all_turkish_urls.extend(urls)

print(f"\nToplamda {len(all_turkish_urls)} adet Türkçe URL bulundu.")
print("\nWARC dosyalarındaki Türkçe URL sayıları:\n", all_turkish_urls_counts)

# all_turkish_urls listesinde bulunan tüm URL'lerden unique domain'leri alalım
unique_domains = {urlparse(url).netloc for url in all_turkish_urls if url}

print("Unique domains:", unique_domains)
for domain in unique_domains:
    print(domain)

# unique_domains değişkeninin oluşturulmuş olduğunu varsayıyoruz.
with open('./websites/warc-turkish-url-list.txt', 'w', encoding='utf-8') as f:
    for domain in sorted(unique_domains):
        f.write(domain + "\n")

print(f"Exported {len(unique_domains)} domains to warc-turkish-url-list.txt")
# Out:
# Processing WARC files: 100%|██████████| 31/31 [11:40<00:00, 22.58s/it]
# Toplamda 35975 adet Türkçe URL bulundu.
#
# WARC dosyalarındaki Türkçe URL sayıları:
#  {'./data/CC-NEWS-20250103095544-00180.warc': 1979, './data/CC-NEWS-20250102092617-00168.warc': 1328, './data/CC-NEWS-20250101055537-00157.warc': 1257, './data/CC-NEWS-20250101233509-00164.warc': 320, './data/CC-NEWS-20250102214004-00175.warc': 960, './data/CC-NEWS-20250103181014-00185.warc': 826, './data/CC-NEWS-20250103145501-00183.warc': 1302, './data/CC-NEWS-20250101110352-00159.warc': 1441, './data/CC-NEWS-20250102074538-00167.warc': 1222, './data/CC-NEWS-20250102110149-00169.warc': 1750, './data/CC-NEWS-20200110212037-00310.warc': 1598, './data/CC-NEWS-20250102140759-00171.warc': 1345, './data/CC-NEWS-20250102053830-00166.warc': 841, './data/CC-NEWS-20250103060152-00178.warc': 1224, './data/CC-NEWS-20250101182853-00162.warc': 1537, './data/CC-NEWS-20250102155145-00172.warc': 954, './data/CC-NEWS-20250101204758-00163.warc': 616, './data/CC-NEWS-20250103080404-00179.warc': 1347, './data/CC-NEWS-20250102192440-00174.warc': 763, './data/CC-NEWS-20250102122438-00170.warc': 1347, './data/CC-NEWS-20250102173620-00173.warc': 1170, './data/CC-NEWS-20250103114344-00181.warc': 1250, './data/CC-NEWS-20250101083312-00158.warc': 1814, './data/CC-NEWS-20250101160900-00161.warc': 1013, './data/CC-NEWS-20250103031223-00177.warc': 820, './data/CC-NEWS-20250103000559-00176.warc': 367, './data/CC-NEWS-20250101133323-00160.warc': 1282, './data/CC-NEWS-20250103131849-00182.warc': 1509, './data/CC-NEWS-20250103163233-00184.warc': 1042, './data/CC-NEWS-20250101020153-00156.warc': 803, './data/CC-NEWS-20250102025043-00165.warc': 948}
# Unique domains: {'news.yam.md', 'www.onvista.de', 'www.blabbermouth.net', 'www.yenigungazetesi.net', 'www.zdf.de', 'www.guneyege.net', 'www.aksutvhaber.net', 'www.anadolupress.com', 'www.teknoscrool.com', 'www.3szek.ro', 'www.elbistaninsesi.com', 'www.ispartahaber.com.tr', 'report.az', 'www.wo-was.de', 'www.sofra.com.tr', 'www.haberturk.com', 'www.cumhuriyet.com.tr', 'hyetert.org', 'www.tvsoap.it', 'www.trthaber.com', 'www.bluewin.ch', 'www.boluolay.com', 'webcatalog.io', 'www.ulusal.com.tr', 'www.portfolio.hu', 'www.kibrisgenctv.com', 'www.cepkolik.com', 'www.allgaeuer-zeitung.de', 'www.idman.biz', 'www.yildirimgazetesi.com', 'ru.euronews.com', 'www.nationalturk.com', 'www.shk-journal.de', 'www.yenicaggazetesi.com.tr', 'www.tgrthaber.com', 'www.haber50.com', 'www.ekovitrin.com', 'www.nickles.de', 'www.birgun.net', 'www.yeniasir.com.tr', 'www.kontextwochenzeitung.de', 'kralspor.ensonhaber.com', 'www.ndr.de', 'www.yenisafak.com', 'www.globenewswire.com', 'www.apara.com.tr', 'www.detaykibris.com', 'borusannext.com', 'www.yenikonya.com.tr', 'www.finanzen.net', 'www.aydinses.com', 'www.sha.com.tr', 'www.fikriyat.com', 'ruyatabirleri.aksam.com.tr', 'www.istanbultimes.com.tr', 'www.t-online.de', 'siol.net', 'www.inar.de', 'www.autoshow.com.tr', 'www.yeniduzen.com', 'www.aa.com.tr', 'www.bayburtgundem.com', 'www.gea.de', 'www.goal.com', 'bianet.org', 'www.corumhakimiyet.net', 'www.bizimakyazi.com', 'sadibey.com', 'www.boerse-online.de', 'www.extremnews.com', 'www.internethaber.com', 'haber.sol.org.tr', 'morpapatyaekstra.aksam.com.tr', 'www.havadiskibris.com', 'webmasto.com', 'www.radiox.de', 'www.samanyoluhaber.com', 'tr.oliveoiltimes.com', 'www.yanoticias.es', 'www.insuedthueringen.de', 'www.bolgegundem.com.tr', 'www.epochtimes.de', 'kinder.wdr.de', 'www.wallstreet-online.de', 'bigpara.hurriyet.com.tr', 'de.indymedia.org', 'www.hyundai.com', 'onedio.com', 'www.newsbeast.gr', 'm.haberler.com', 'infocity.tech', 'www.milliyet.com.tr', 'kroonika.delfi.ee', 'www.vatandanhaber.com', 'www.alphafreepress.gr', 'notebook.yesky.com', 'www.macerkopf.de', 'www.haberelazig.com', 'az.irna.ir', 'www.swr.de', 'www.ramasuri.de', 'www.srf.ch', 'www.iha.com.tr', 'www.724dinle.com', 'www.augsburger-allgemeine.de', 'en.mehrnews.com', 'www.origo.hu', '444.hu', '1news.az', 'www.haberport.com', 'www.haberingundemi.com', 'www.tuncbilekreklam.com.tr', 'www.hisse.net', 'www.ekonomist.com.tr', 'www.sueddeutsche.de', 'www.gazetevatan.com', 'www.vavtv.com.tr', 'www.urfa.com', 'www.stuttgarter-nachrichten.de', 'www.vaticannews.va', 'metbuat.az', 'odatv.com', 'www.schwarzwaelder-bote.de', 'www.amerikaninsesi.org', 'golazo.ro', 'www.ensonhaber.com', 'www.haberekspres.com.tr', 'www.sportschau.de', 'diy.yesky.com', 'www.cumrapostasi.com', 'files.dainikshiksha.com', 'tr.sputniknews.com', 'www.swrfernsehen.de', 'www.zerohedge.com', 'www.gundemkibris.com', 'www.adiyamanlilar.net', 'uzmanpara.milliyet.com.tr', 'www.blikk.hu', 'www.ariananews.af', 'www.capital.com.tr', 'www.fanatik.com.tr', 'thelinkpaper.ca', 'www.fityasa.com.tr', 'carmedya.com', 'turan.az', 'www.nhtalkradio.com', 'www.bolgegundem.com', 'www.gebzegazetesi.com', 'www.aljazeera.net', 'www1.wdr.de', 'www.antimafiaduemila.com', 'news.yam.ro', 'www.dailysabah.com', 'www.magyarkurir.hu', 'tr.irna.ir', 'www.prosieben.de', 'm.haberturk.com', 'anlatilaninotesi.com.tr', 'www.webtekno.com', 'www.kent09.com.tr', 'news.day.az', 'www.quotidiano.net', 'www.diyaloggazetesi.com', 'htkulup.haberturk.com', 'business-panorama.de', 'sport.postimees.ee', 'tr.mehrnews.com', 'www.turkiyegazetesi.com.tr', 'www.jungewelt.de', 'hthayat.haberturk.com', 'www.snobmagazin.com', 'www.hazipatika.com', 'www.fotomac.com.tr', 'hezarfendergi.com', 'ap-verlag.de', 'iyiortagololur.blogspot.com', 'thp.org.vn', 'www.diken.com.tr', 'www.brisant.de', 'www.bumm.sk', 'www.schwaebische.de', 'www.mersintime.com', 'www.yedigunhaber.com', 'www.worldtribune.com', 'www.spox.com', 'www.moritz.de', 'haberkonseyi.com', 'stockholmcf.org', 'www.donanimhaber.com ...
# news.yam.md
# www.onvista.de
# www.blabbermouth.net
# www.yenigungazetesi.net
# www.zdf.de
# www.guneyege.net
# www.aksutvhaber.net
# www.anadolupress.com
# www.teknoscrool.com
# www.3szek.ro
# www.elbistaninsesi.com
# www.ispartahaber.com.tr
# report.az
# www.wo-was.de
# www.sofra.com.tr
# www.haberturk.com
# www.cumhuriyet.com.tr
# hyetert.org
# www.tvsoap.it
# www.trthaber.com
# www.bluewin.ch
# www.boluolay.com
# webcatalog.io
# www.ulusal.com.tr
# www.portfolio.hu
# www.kibrisgenctv.com
# www.cepkolik.com
# www.allgaeuer-zeitung.de
# www.idman.biz
# www.yildirimgazetesi.com
# ru.euronews.com
# www.nationalturk.com
# www.shk-journal.de
# www.yenicaggazetesi.com.tr
# www.tgrthaber.com
# www.haber50.com
# www.ekovitrin.com
# www.nickles.de
# www.birgun.net
# www.yeniasir.com.tr
# www.kontextwochenzeitung.de
# kralspor.ensonhaber.com
# www.ndr.de
# www.yenisafak.com
# www.globenewswire.com
# www.apara.com.tr
# www.detaykibris.com
# borusannext.com
# www.yenikonya.com.tr
# www.finanzen.net
# www.aydinses.com
# www.sha.com.tr
# www.fikriyat.com
# ruyatabirleri.aksam.com.tr
# www.istanbultimes.com.tr
# www.t-online.de
# siol.net
# www.inar.de
# www.autoshow.com.tr
# www.yeniduzen.com
# www.aa.com.tr
# www.bayburtgundem.com
# www.gea.de
# www.goal.com
# bianet.org
# www.corumhakimiyet.net
# www.bizimakyazi.com
# sadibey.com
# www.boerse-online.de
# www.extremnews.com
# www.internethaber.com
# haber.sol.org.tr
# morpapatyaekstra.aksam.com.tr
# www.havadiskibris.com
# webmasto.com
# www.radiox.de
# www.samanyoluhaber.com
# tr.oliveoiltimes.com
# www.yanoticias.es
# www.insuedthueringen.de
# www.bolgegundem.com.tr
# www.epochtimes.de
# kinder.wdr.de
# www.wallstreet-online.de
# bigpara.hurriyet.com.tr
# de.indymedia.org
# www.hyundai.com
# onedio.com
# www.newsbeast.gr
# m.haberler.com
# infocity.tech
# www.milliyet.com.tr
# kroonika.delfi.ee
# www.vatandanhaber.com
# www.alphafreepress.gr
# notebook.yesky.com
# www.macerkopf.de
# www.haberelazig.com
# az.irna.ir
# www.swr.de
# www.ramasuri.de
# www.srf.ch
# www.iha.com.tr
# www.724dinle.com
# www.augsburger-allgemeine.de
# en.mehrnews.com
# www.origo.hu
# 444.hu
# 1news.az
# www.haberport.com
# www.haberingundemi.com
# www.tuncbilekreklam.com.tr
# www.hisse.net
# www.ekonomist.com.tr
# www.sueddeutsche.de
# www.gazetevatan.com
# www.vavtv.com.tr
# www.urfa.com
# www.stuttgarter-nachrichten.de
# www.vaticannews.va
# metbuat.az
# odatv.com
# www.schwarzwaelder-bote.de
# www.amerikaninsesi.org
# golazo.ro
# www.ensonhaber.com
# www.haberekspres.com.tr
# www.sportschau.de
# diy.yesky.com
# www.cumrapostasi.com
# files.dainikshiksha.com
# tr.sputniknews.com
# www.swrfernsehen.de
# www.zerohedge.com
# www.gundemkibris.com
# www.adiyamanlilar.net
# uzmanpara.milliyet.com.tr
# www.blikk.hu
# www.ariananews.af
# www.capital.com.tr
# www.fanatik.com.tr
# thelinkpaper.ca
# www.fityasa.com.tr
# carmedya.com
# turan.az
# www.nhtalkradio.com
# www.bolgegundem.com
# www.gebzegazetesi.com
# www.aljazeera.net
# www1.wdr.de
# www.antimafiaduemila.com
# news.yam.ro
# www.dailysabah.com
# www.magyarkurir.hu
# tr.irna.ir
# www.prosieben.de
# m.haberturk.com
# anlatilaninotesi.com.tr
# www.webtekno.com
# www.kent09.com.tr
# news.day.az
# www.quotidiano.net
# www.diyaloggazetesi.com
# htkulup.haberturk.com
# business-panorama.de
# sport.postimees.ee
# tr.mehrnews.com
# www.turkiyegazetesi.com.tr
# www.jungewelt.de
# hthayat.haberturk.com
# www.snobmagazin.com
# www.hazipatika.com
# www.fotomac.com.tr
# hezarfendergi.com
# ap-verlag.de
# iyiortagololur.blogspot.com
# thp.org.vn
# www.diken.com.tr
# www.brisant.de
# www.bumm.sk
# www.schwaebische.de
# www.mersintime.com
# www.yedigunhaber.com
# www.worldtribune.com
# www.spox.com
# www.moritz.de
# haberkonseyi.com
# stockholmcf.org
# www.donanimhaber.com
# www.tagesschau.de
# www.nd-aktuell.de
# www.takvim.com.tr
# www.polizei.bayern.de
# www.corumhaber.net
# www.azathabar.com
# www.neues-deutschland.de
# t24.com.tr
# www.vezess.hu
# www.kayserigundem.com.tr
# skor.sozcu.com.tr
# www.mynet.com
# www.berlin.de
# www.halkinsesikibris.com
# www.kosmo.at
# weltjournal.de
# www.haberler.com
# www.kibrismanset.com
# www.ntv.com.tr
# www.sirtcantam.com.tr
# www.direktbroker.de
# www.teknobeyin.com
# www.kiel-magazin.de
# pressemitteilung.ws
# www.sondakika.com
# www.hurriyet.com.tr
# www.aspor.com.tr
# www.haufe.de
# www.yeniasya.com.tr
# otogundem.com.tr
# estaticos-cdn.prensaiberica.es
# www.dw.com
# www.insider.gr
# www.prnewswire.com
# crimethinc.com
# www.boersennews.de
# www.anews.com.tr
# hirtv.hu
# www.atv.com.tr
# tr.steelorbis.com
# quran.com
# appmaster.io
# www.ekonomim.com
# www.haber3.com
# www.finanznachrichten.de
# www.virahaber.com
# www.krone.at
# www.weltfussball.de
# www.ahaber.com.tr
# www.gecce.com.tr
# www.inka-magazin.de
# www.derwesten.de
# www.sozcu.com.tr
# kultur.net
# www.sabah.com.tr
# www.wanhaber.com
# www.mopo.de
# www.avaya.com
# www.tag24.de
# www.odatv.com
# www.voltairenet.org
# www.bundestag.de
# www.mlpd.de
# sporekstra.aksam.com.tr
# www.gercekgundem.com
# www.dunya.com
# finans.mynet.com
# www.evrensel.net
# magdergi.com
# www.hurriyetdailynews.com
# hurfikirler.com
# www.sporx.com
# maisfutebol.iol.pt
# mediasetinfinity.mediaset.it
# haberkibris.com
# www.elele.com.tr
# www.laola1.at
# www.tamindir.com
# www.nachrichten.at
# www.austrianwings.info
# Exported 269 domains to warc-turkish-url-list.txt

# %% [markdown]
# ### Merge WARC URLs with BIK URLs

# %%
# "basin-ilan-kurumu-websites.txt" dosyasını okuyalım
bik_file_path = './websites/basin-ilan-kurumu-websites.txt'
with open(bik_file_path, 'r', encoding='utf-8') as bik_file:
    bik_urls = {line.strip().lstrip('www.') for line in bik_file if line.strip()}

# "warc-turkish-url-list.txt" dosyasını okuyalım
warc_file_path = './websites/warc-turkish-url-list.txt'
with open(warc_file_path, 'r', encoding='utf-8') as warc_file:
    warc_urls = {line.strip().lstrip('www.') for line in warc_file if line.strip()}

# İki seti birleştirip unique hale getirelim
all_urls = bik_urls.union(warc_urls)

# Sonuçları "all-websites.txt" dosyasına yazalım
output_file_path = './websites/all-websites.txt'
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for url in sorted(all_urls):
        output_file.write(url + '\n')

print(f"Toplam {len(all_urls)} unique URL 'all-websites.txt' dosyasına kaydedildi.")
# Out:
# Toplam 1339 unique URL 'all-websites.txt' dosyasına kaydedildi.
